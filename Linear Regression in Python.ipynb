# %%
import pandas as pd

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris[iris['SepalWidthCm']>4]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa

# %%
iris[iris['PetalWidthCm']>1]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
iris[iris['PetalWidthCm']>2]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 112  113            6.8           3.0            5.5           2.1
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# 124  125            6.7           3.3            5.7           2.1
# 128  129            6.4           2.8            5.6           2.1
# ...

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data = iris,hue='Species')
plt.show()

# %%
#now apply linear regression

# %%
#independent variable
y = iris[['SepalLengthCm']]

# %%
y.head()
# Out:
#    SepalLengthCm
# 0            5.1
# 1            4.9
# 2            4.7
# 3            4.6
# 4            5.0

# %%
#dependent variable
x = iris[['SepalWidthCm']]

# %%
x.head()
# Out:
#    SepalWidthCm
# 0           3.5
# 1           3.0
# 2           3.2
# 3           3.1
# 4           3.6

# %%
#now divide this data in training and testing data set

# %%
from sklearn.model_selection import train_test_split

# %%
#sikit learn is a library in python used in linear regression, logistic regression, decision tree, random forest, etc.

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)
#here sequence is very important to note

# %%
x_train.head()
# Out:
#      SepalWidthCm
# 49            3.3
# 103           2.9
# 117           3.8
# 69            2.5
# 10            3.7

# %%
x_test.head()
# Out:
#      SepalWidthCm
# 19            3.8
# 52            3.1
# 146           2.5
# 109           3.6
# 60            2.0

# %%
y_train.head()
# Out:
#      SepalLengthCm
# 49             5.0
# 103            6.3
# 117            7.7
# 69             5.6
# 10             5.4

# %%
y_test.head()
# Out:
#      SepalLengthCm
# 19             5.1
# 52             6.9
# 146            6.3
# 109            7.2
# 60             5.0

# %%
#now apply linear regression model on this data

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_test.head()
# Out:
#      SepalLengthCm
# 19             5.1
# 52             6.9
# 146            6.3
# 109            7.2
# 60             5.0

# %%
y_pred[:5]
# Out:
# array([[5.65700665],
#        [5.86010941],
#        [6.03419749],
#        [5.71503601],
#        [6.17927089]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.7876955904735614

# %%
#model -  2    (using multiple regression)

# %%
y = iris[['SepalLengthCm']]

# %%
x = iris[['SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
lr2 = LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.1026230101542737

# %%
#this is significantly lower than the earlier model's mean squared error

# %%
#hence our model-2 is much more accurate as compared to the model-1
