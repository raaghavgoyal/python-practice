# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
marvel = pd.read_csv('marvel_demo_stats_powers.csv')

# %%
marvel.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x  Gender EyeColor  \
# 0           0   0         A-Bomb        good    Male   yellow
# 1           1   3    Abomination         bad    Male    green
# 2           2   4        Abraxas         bad    Male     blue
# 3           3   5  Absorbing Man         bad    Male     blue
# 4           4   8       Agent 13        good  Female     blue
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 0              Human   No Hair  Marvel Comics         -  ...         False
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 4                  -     Blond  Marvel Comics         -  ...           NaN
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
marvel.shape
# Out:
# (382, 186)

# %%
marvel['Alignment_x'].value_counts()
# Out:
# Alignment_x
# good       254
# bad        114
# neutral     11
# -            3
# Name: count, dtype: int64

# %%
c_names = marvel.columns.tolist()
#print(c)
for c in c_names:
    print(c)
# Out:
# Unnamed: 0
# ID
# Name
# Alignment_x
# Gender
# EyeColor
# Race
# HairColor
# Publisher
# SkinColor
# Height
# Weight
# Intelligence_x
# Strength
# Speed
# Durability_x
# Power
# Combat
# Total
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Durability_y
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Intelligence_y
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# ...

# %%
marvel[marvel['Alignment_x']=='bad'].sort_values(by = ['Total'])[:100]
# Out:
#      Unnamed: 0   ID              Name Alignment_x  Gender EyeColor  \
# 378         378  727       Yellow Claw         bad    Male     blue
# 272         272  546     Razor-Fist II         bad    Male     blue
# 254         254  500         Omega Red         bad    Male      red
# 229         229  460   Mister Sinister         bad    Male      red
# 200         200  400  Lady Deathstrike         bad  Female    brown
# ..          ...  ...               ...         ...     ...      ...
# 2             2    4           Abraxas         bad    Male     blue
# 215         215  425             Magus         bad    Male    black
# 118         118  231          Dormammu         bad    Male   yellow
# 3             3    5     Absorbing Man         bad    Male     blue
# 8             8   12              Ajax         bad    Male    brown
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# ...

# %%
marvel[marvel['Name']=='Thanos']
# Out:
#      Unnamed: 0   ID    Name Alignment_x Gender EyeColor     Race HairColor  \
# 328         328  657  Thanos         bad   Male      red  Eternal   No Hair
#
#          Publisher SkinColor  ...  Web Creation  Reality Warping  Odin Force  \
# 328  Marvel Comics    purple  ...         False             True       False
#
#      Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 328             False        False          False                  False
#
#      Vision - Cryo  Omnipresent Omniscient
# 328          False        False      False
#
# [1 rows x 186 columns]

# %%
marvel[marvel['Race']=='God / Eternal']
# Out:
#      Unnamed: 0   ID              Name Alignment_x Gender EyeColor  \
# 35           35   79          Beyonder        good   Male        -
# 80           80  159    Captain Planet        good   Male      red
# 81           81  160  Captain Universe        good      -        -
# 253         253  498              Odin        good   Male     blue
#
#               Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 35   God / Eternal         -  Marvel Comics         -  ...         False
# 80   God / Eternal     Green  Marvel Comics         -  ...         False
# 81   God / Eternal         -  Marvel Comics         -  ...         False
# 253  God / Eternal     White  Marvel Comics         -  ...         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 35              True       False             False        False
# 80             False       False             False        False
# 81             False       False             False        False
# ...

# %%
good = marvel[marvel['Alignment_x']=='good']

# %%
good.head()
# Out:
#     Unnamed: 0  ID        Name Alignment_x  Gender EyeColor   Race HairColor  \
# 0            0   0      A-Bomb        good    Male   yellow  Human   No Hair
# 4            4   8    Agent 13        good  Female     blue      -     Blond
# 5            5   9   Agent Bob        good    Male    brown  Human     Brown
# 6            6  10  Agent Zero        good    Male        -      -         -
# 10          10  22       Angel        good    Male     blue      -     Blond
#
#         Publisher SkinColor  ...  Web Creation  Reality Warping  Odin Force  \
# 0   Marvel Comics         -  ...         False            False       False
# 4   Marvel Comics         -  ...           NaN              NaN         NaN
# 5   Marvel Comics         -  ...         False            False       False
# 6   Marvel Comics         -  ...         False            False       False
# 10  Marvel Comics         -  ...         False            False       False
#
# ...

# %%
good.sort_values(by=['Speed'], ascending = False)
# Out:
#      Unnamed: 0   ID            Name Alignment_x  Gender      EyeColor  \
# 183         183  349  Jack of Hearts        good    Male  blue / white
# 43           43   95      Black Bolt        good    Male          blue
# 321         321  633        Stardust        good    Male             -
# 252         252  497         Nova II        good  Female         white
# 270         270  538     Quicksilver        good    Male          blue
# ..          ...  ...             ...         ...     ...           ...
# 262         262  524         Polaris        good  Female         green
# 300         300  597            Silk        good  Female         brown
# 311         311  621     Spider-Gwen        good  Female          blue
# 320         320  632       Star-Lord        good    Male          blue
# 342         342  679          Triton        good    Male         green
#
#                Race HairColor      Publisher SkinColor  ...  Web Creation  \
# ...

# %%
good.sort_values(by=['Total'], ascending = False)
# Out:
#      Unnamed: 0   ID         Name Alignment_x  Gender EyeColor           Race  \
# 321         321  633     Stardust        good    Male        -              -
# 330         330  661         Thor        good    Male     blue      Asgardian
# 251         251  496         Nova        good    Male    brown          Human
# 184         184  355    Jean Grey        good  Female    green         Mutant
# 260         260  518      Phoenix        good  Female    green         Mutant
# ..          ...  ...          ...         ...     ...      ...            ...
# 262         262  524      Polaris        good  Female    green         Mutant
# 300         300  597         Silk        good  Female    brown          Human
# 311         311  621  Spider-Gwen        good  Female     blue          Human
# 320         320  632    Star-Lord        good    Male     blue  Human-Spartoi
# 342         342  679       Triton        good    Male    green        Inhuman
#
# ...

# %%
good.sort_values(by=['Power'], ascending = False)
# Out:
#      Unnamed: 0   ID         Name Alignment_x  Gender EyeColor  \
# 252         252  497      Nova II        good  Female    white
# 177         177  338       Iceman        good    Male    brown
# 43           43   95   Black Bolt        good    Male     blue
# 260         260  518      Phoenix        good  Female    green
# 35           35   79     Beyonder        good    Male        -
# ..          ...  ...          ...         ...     ...      ...
# 262         262  524      Polaris        good  Female    green
# 300         300  597         Silk        good  Female    brown
# 311         311  621  Spider-Gwen        good  Female     blue
# 320         320  632    Star-Lord        good    Male     blue
# 342         342  679       Triton        good    Male    green
#
#                Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 252  Human / Cosmic       Red  Marvel Comics      gold  ...         False
# ...

# %%
good_max_power_full = good[good['Power']==100]

# %%
good_max_power_full.head()
# Out:
#      Unnamed: 0   ID            Name Alignment_x Gender EyeColor  \
# 34           34   78   Beta Ray Bill        good   Male        -
# 35           35   79        Beyonder        good   Male        -
# 43           43   95      Black Bolt        good   Male     blue
# 73           73  144           Cable        good   Male     blue
# 115         115  225  Doctor Strange        good   Male     grey
#
#               Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 34               -   No Hair  Marvel Comics         -  ...         False
# 35   God / Eternal         -  Marvel Comics         -  ...         False
# 43         Inhuman     Black  Marvel Comics         -  ...         False
# 73          Mutant     White  Marvel Comics         -  ...         False
# 115          Human     Black  Marvel Comics         -  ...         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 34             False       False             False        False
# ...

# %%
good_max_power_full.shape
# Out:
# (19, 186)

# %%
plt.bar(list(good_max_power_full['Name'])[0:5],list(good_max_power_full['Total'])[:5],color = 'g')
# Out:
# <BarContainer object of 5 artists>

# %%
bad = marvel[marvel['Alignment_x']=='bad']

# %%
bad.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x Gender EyeColor  \
# 1           1   3    Abomination         bad   Male    green
# 2           2   4        Abraxas         bad   Male     blue
# 3           3   5  Absorbing Man         bad   Male     blue
# 7           7  11     Air-Walker         bad   Male     blue
# 8           8  12           Ajax         bad   Male    brown
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 7                  -     White  Marvel Comics         -  ...         False
# 8             Cyborg     Black  Marvel Comics         -  ...         False
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
bad.sort_values(by=['Speed'],ascending=False).head()
# Out:
#      Unnamed: 0   ID           Name Alignment_x Gender EyeColor  \
# 7             7   11     Air-Walker         bad   Male     blue
# 129         129  251  Fallen One II         bad   Male    black
# 120         120  234            Ego         bad      -        -
# 118         118  231       Dormammu         bad   Male   yellow
# 2             2    4        Abraxas         bad   Male     blue
#
#               Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 7                -     White  Marvel Comics         -  ...         False
# 129              -      Blue  Marvel Comics         -  ...         False
# 120              -         -  Marvel Comics         -  ...         False
# 118              -   No Hair  Marvel Comics         -  ...         False
# 2    Cosmic Entity     Black  Marvel Comics         -  ...         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 7              False       False             False        False
# ...

# %%
bad.sort_values(by=['Intelligence_x'],ascending = False).head()
# Out:
#      Unnamed: 0   ID         Name Alignment_x Gender EyeColor    Race  \
# 218         218  430     Mandarin         bad   Male     blue   Human
# 17           17   34   Apocalypse         bad   Male      red  Mutant
# 194         194  378         Kang         bad   Male    brown       -
# 112         112  221  Doctor Doom         bad   Male    brown   Human
# 339         339  670     Tinkerer         bad   Male    brown       -
#
#     HairColor      Publisher SkinColor  ...  Web Creation  Reality Warping  \
# 218     White  Marvel Comics         -  ...         False            False
# 17      Black  Marvel Comics      grey  ...         False            False
# 194     Brown  Marvel Comics         -  ...         False            False
# 112     Brown  Marvel Comics         -  ...         False            False
# 339     White  Marvel Comics         -  ...         False            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
bad.sort_values(by=['Total'],ascending = False).head()
# Out:
#      Unnamed: 0   ID           Name Alignment_x Gender EyeColor  \
# 118         118  231       Dormammu         bad   Male   yellow
# 215         215  425          Magus         bad   Male    black
# 2             2    4        Abraxas         bad   Male     blue
# 129         129  251  Fallen One II         bad   Male    black
# 256         256  504      Onslaught         bad   Male      red
#
#               Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 118              -   No Hair  Marvel Comics         -  ...         False
# 215              -         -  Marvel Comics         -  ...         False
# 2    Cosmic Entity     Black  Marvel Comics         -  ...         False
# 129              -      Blue  Marvel Comics         -  ...         False
# 256         Mutant   No Hair  Marvel Comics         -  ...         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 118            False       False             False        False
# ...

# %%
#making a histogram for speed for good superheroes
plt.hist(good['Speed'])
plt.title('Distribution of speed (Good)')
plt.xlabel('Speed')
plt.show()

# %%
#Making a histogram for combat for supervillains
plt.hist(bad['Combat'])
plt.title('Distribution of combat(Good)')
plt.xlabel('Combat')
plt.ylabel('Count')
plt.show()

# %%
marvel_total = marvel[['Name','Total']]

# %%
marvel_total[:50]
# Out:
#                 Name  Total
# 0             A-Bomb  316.0
# 1        Abomination  436.0
# 2            Abraxas  526.0
# 3      Absorbing Man    NaN
# 4           Agent 13    NaN
# 5          Agent Bob   61.0
# 6         Agent Zero  388.0
# 7         Air-Walker  460.0
# 8               Ajax    NaN
# 9               Ammo    5.0
# 10             Angel  245.0
# 11        Angel Dust    NaN
# 12   Angel Salvadore  210.0
# 13         Annihilus  381.0
# 14           Ant-Man  225.0
# 15        Ant-Man II  184.0
# 16        Anti-Venom  459.0
# 17        Apocalypse  493.0
# 18           Arachne    5.0
# 19         Archangel  268.0
# 20          Arclight  288.0
# 21            Ardina    NaN
# 22              Ares  435.0
# 23             Ariel  186.0
# 24             Armor  314.0
# 25             Atlas  363.0
# 26            Aurora  329.0
# 27            Azazel  370.0
# 28           Banshee  290.0
# 29            Bantam  232.0
# 30        Battlestar  334.0
# 31              Beak    5.0
# ...
