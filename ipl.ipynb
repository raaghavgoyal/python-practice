# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#loading the ipl matches dataset
ipl = pd.read_csv('matches.csv')

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl.shape
# Out:
# (1095, 20)

# %%
ipl['player_of_match'].value_counts()
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64

# %%
ipl['player_of_match'].value_counts()[:10]
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
list(ipl['player_of_match'].value_counts()[:5].keys())
# Out:
# ['AB de Villiers', 'CH Gayle', 'RG Sharma', 'DA Warner', 'V Kohli']

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ipl['player_of_match'].value_counts()[:5].keys()),list(ipl['player_of_match'].value_counts()[0:5]),color='g')
plt.show()

# %%
ipl['result'].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            122
# Rajasthan Royals               120
# Royal Challengers Bangalore    113
# Sunrisers Hyderabad             88
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Delhi Capitals                  50
# Deccan Chargers                 43
# Punjab Kings                    24
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Royal Challengers Bengaluru      8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
batting_first = ipl[ipl['result']=='runs']

# %%
batting_first
# Out:
#            id   season        city        date   match_type player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League     BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League      MEK Hussey
# 7      335989  2007/08     Chennai  2008-04-23       League       ML Hayden
# 9      335991  2007/08  Chandigarh  2008-04-25       League   KC Sangakkara
# 14     335996  2007/08   Bangalore  2008-04-28       League        MS Dhoni
# ...       ...      ...         ...         ...          ...             ...
# 1085  1426300     2024   Bengaluru  2024-05-12       League         C Green
# 1086  1426302     2024       Delhi  2024-05-14       League        I Sharma
# 1088  1426305     2024      Mumbai  2024-05-17       League        N Pooran
# 1089  1426306     2024   Bengaluru  2024-05-18       League    F du Plessis
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2   Shahbaz Ahmed
#
# ...

# %%
plt.hist(batting_first['result_margin'])
plt.title('Distribution of Runs')
plt.xlabel('Runs')
plt.show()

# %%
batting_first['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 71
# Chennai Super Kings            71
# Kolkata Knight Riders          54
# Royal Challengers Bangalore    53
# Sunrisers Hyderabad            44
# Rajasthan Royals               43
# Kings XI Punjab                40
# Delhi Daredevils               25
# Delhi Capitals                 21
# Deccan Chargers                18
# Lucknow Super Giants           16
# Gujarat Titans                 11
# Punjab Kings                   11
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Royal Challengers Bengaluru     4
# Rising Pune Supergiants         2
# Kochi Tuskers Kerala            2
# Gujarat Lions                   1
# Name: count, dtype: int64

# %%
plt.bar(list(batting_first['winner'].value_counts()[:3].keys()),list(batting_first['winner'].value_counts()[:3]),color=['blue','yellow','purple'])
plt.show()

# %%
plt.pie(list(batting_first['winner'].value_counts()),labels = list(batting_first['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
batting_second = ipl[ipl['result']=='wickets']

# %%
batting_second.head()
# Out:
#        id   season       city        date match_type player_of_match  \
# 2  335984  2007/08      Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08     Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08    Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08     Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08  Hyderabad  2008-04-22     League        V Sehwag
#
#                                        venue                  team1  \
# 2                           Feroz Shah Kotla       Delhi Daredevils
# 3                           Wankhede Stadium         Mumbai Indians
# 4                               Eden Gardens  Kolkata Knight Riders
# 5                     Sawai Mansingh Stadium       Rajasthan Royals
# 6  Rajiv Gandhi International Stadium, Uppal        Deccan Chargers
#
#                          team2       toss_winner toss_decision  \
# 2             Rajasthan Royals  Rajasthan Royals           bat
# ...

# %%
plt.figure(figsize=(7,7))
plt.hist(batting_second['result_margin'])
plt.title('Batting Second wins')
plt.xlabel('wickets')
plt.ylabel('wins')
# Out:
# Text(0, 0.5, 'wins')

# %%
batting_second['winner'].value_counts()
# Out:
# winner
# Kolkata Knight Riders          76
# Mumbai Indians                 71
# Rajasthan Royals               67
# Chennai Super Kings            67
# Royal Challengers Bangalore    61
# Kings XI Punjab                45
# Sunrisers Hyderabad            43
# Delhi Daredevils               42
# Delhi Capitals                 24
# Gujarat Titans                 17
# Punjab Kings                   13
# Gujarat Lions                  12
# Deccan Chargers                11
# Lucknow Super Giants            8
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Royal Challengers Bengaluru     3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
plt.bar(list(batting_second['winner'].value_counts()[:3].keys()),list(batting_second['winner'].value_counts()[:3]),color=['purple','blue','orange'])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(batting_second['winner'].value_counts()),labels=list(batting_second['winner'].value_counts().keys()),autopct = '%0.1f%%')
plt.show()

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl['season'].value_counts()
# Out:
# season
# 2013       76
# 2023       74
# 2012       74
# 2022       74
# 2011       73
# 2024       71
# 2018       60
# 2021       60
# 2020/21    60
# 2019       60
# 2016       60
# 2014       60
# 2009/10    60
# 2017       59
# 2015       59
# 2007/08    58
# 2009       57
# Name: count, dtype: int64

# %%
ipl['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
import numpy as np

# %%
np.sum(ipl['toss_winner']==ipl['winner'])
# Out:
# 554

# %%
ipl.shape
# Out:
# (1095, 20)

# %%
554/1095
# Out:
# 0.5059360730593607

# %%
deliveries = pd.read_csv('deliveries.csv')

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
deliveries['match_id'].unique()
# Out:
# array([ 335982,  335983,  335984, ..., 1426310, 1426311, 1426312],
#       dtype=int64)

# %%
len(deliveries['match_id'].unique())
# Out:
# 1095

# %%
match_1 = deliveries[deliveries['match_id']==335982]

# %%
match_1.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
deliveries.sort_values(by='match_id')
# Out:
#         match_id  inning                 batting_team  \
# 0         335982       1        Kolkata Knight Riders
# 143       335982       2  Royal Challengers Bangalore
# 144       335982       2  Royal Challengers Bangalore
# 145       335982       2  Royal Challengers Bangalore
# 146       335982       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 260799   1426312       1          Sunrisers Hyderabad
# 260800   1426312       1          Sunrisers Hyderabad
# 260801   1426312       1          Sunrisers Hyderabad
# 260792   1426312       1          Sunrisers Hyderabad
# 260919   1426312       2        Kolkata Knight Riders
#
#                        bowling_team  over  ball      batter         bowler  \
# 0       Royal Challengers Bangalore     0     1  SC Ganguly        P Kumar
# 143           Kolkata Knight Riders     2     7    W Jaffer       AB Dinda
# 144           Kolkata Knight Riders     3     1    W Jaffer       I Sharma
# ...

# %%
match_1.shape
# Out:
# (225, 17)

# %%
kkr = match_1[match_1['inning']==1]

# %%
kkr.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
kkr['batsman_runs'].value_counts()
# Out:
# batsman_runs
# 0    45
# 1    39
# 4    15
# 6    14
# 2    11
# Name: count, dtype: int64

# %%
kkr['dismissal_kind'].value_counts()
# Out:
# dismissal_kind
# caught    3
# Name: count, dtype: int64

# %%
rcb = match_1[match_1['inning']==2]

# %%
rcb.head()
# Out:
#      match_id  inning                 batting_team           bowling_team  \
# 124    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 125    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 126    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 127    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 128    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
#
#      over  ball    batter    bowler non_striker  batsman_runs  extra_runs  \
# 124     0     1  R Dravid  AB Dinda    W Jaffer             1           0
# 125     0     2  W Jaffer  AB Dinda    R Dravid             0           1
# 126     0     3  W Jaffer  AB Dinda    R Dravid             0           0
# 127     0     4  W Jaffer  AB Dinda    R Dravid             1           0
# 128     0     5  R Dravid  AB Dinda    W Jaffer             1           0
#
# ...

# %%
rcb['batsman_runs'].value_counts()
# Out:
# batsman_runs
# 0    65
# 1    27
# 2     3
# 6     3
# 4     3
# Name: count, dtype: int64

# %%
rcb['batter'].value_counts()
# Out:
# batter
# W Jaffer      18
# P Kumar       17
# AA Noffke     12
# MV Boucher    11
# CL White      10
# Z Khan         8
# SB Joshi       8
# JH Kallis      7
# V Kohli        5
# R Dravid       3
# B Akhil        2
# Name: count, dtype: int64

# %%
rcb['dismissal_kind'].value_counts()
# Out:
# dismissal_kind
# caught     6
# bowled     3
# run out    1
# Name: count, dtype: int64

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl[ipl['id']==335982]
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2
# 0  RE Koertzen
