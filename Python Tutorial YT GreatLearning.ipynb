# %%
#Arithematic Operators

# %%
# +, -, / , *

# %%
a = 10
b = 20

# %%
a,b
# Out:
# (10, 20)

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %%
# >,<,==,!=

# %%
a = 50
b = 100

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
#Logical Operators
# & |

# %%
a = True
b = False

# %%
a & b
# Out:
# False

# %%
a | b
# Out:
# True

# %%
a & a
# Out:
# True

# %%
a | a
# Out:
# True

# %%
b | b
# Out:
# False

# %%
student = "martha"
Student = "juli e "

# %%
student
Student
# Out:
# 'julie'

# %%
student
# Out:
# 'martha'

# %%
Student[-1]
# Out:
# ' '

# %%
student[1:3]
# Out:
# 'ar'

# %%
len(student)
# Out:
# 6

# %%
student.upper()
# Out:
# 'MARTHA'

# %%
student
# Out:
# 'martha'

# %%
student = student.upper()

# %%
sudent
# Out:
# 1

# %%
student
# Out:
# 'martha'

# %%
student.lower()
# Out:
# 'martha'

# %%
student = "my name is John"

# %%
student.replace('is','are')
# Out:
# 'my name are John'

# %%
str_new = 'sparta sparta 300 300 3000 s'

# %%
str_new
# Out:
# 'sparta sparta 300 300 3000 s'

# %%
str_new.count('s')
# Out:
# 3

# %%
student.count('a')
# Out:
# 1

# %%
student
# Out:
# 'my name is John'

# %%
str_new.find('sparta')
# Out:
# 0

# %%
student.split(' ')
# Out:
# ['my', 'name', 'is', 'John']

# %%
my_string = "Hello world is awesome"

# %%
my_string.find('i')
# Out:
# 12

# %%
str_final = 'President Obama is the best President of United States'

# %%
str_final
# Out:
# 'President Obama is the best President of United States'

# %%
str_final.split('e')
# Out:
# ['Pr',
#  'sid',
#  'nt Obama is th',
#  ' b',
#  'st Pr',
#  'sid',
#  'nt of Unit',
#  'd Stat',
#  's']

# %%
print(str_final)
# Out:
# President Obama is the best President of United States

# %%
print(student)
# Out:
# my name is John

# %%
#Tuples

# %%
tup1 = (1,True, 3.14, 5-3j)

# %%
tup1
# Out:
# (1, True, 3.14, (5-3j))

# %%
type(tup1)
# Out:
# tuple

# %%
tup1[1:3]
# Out:
# (True, 3.14)

# %%
tup1[1] = "hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[257], line 1
# ----> 1 tup1[1] = "hello"
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(tup1)
# Out:
# 4

# %%
tup2 = (1,2,3,4)
tup2
# Out:
# (1, 2, 3, 4)

# %%
tup1
# Out:
# (1, True, 3.14, (5-3j))

# %%
tup1+tup2
# Out:
# (1, True, 3.14, (5-3j), 1, 2, 3, 4)

# %%
tup1
# Out:
# (1, True, 3.14, (5-3j))

# %%
tup1*2
# Out:
# (1, True, 3.14, (5-3j), 1, True, 3.14, (5-3j))

# %%
min(tup1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[271], line 1
# ----> 1 min(tup1)
#
# TypeError: '<' not supported between instances of 'complex' and 'int'

# %%
tup = (1,2,3,4,5,6)

# %%
max(tup)
# Out:
# 6

# %%
min(tup)
# Out:
# 1

# %%
#List

# %%
l1 = [1,"sparta",2.14,True]

# %%
l1
# Out:
# [1, 'sparta', 2.14, True]

# %%
type(l1)
# Out:
# list

# %%
l1[-1]
# Out:
# True

# %%
l1[1] = 100

# %%
l1
# Out:
# [1, 100, 2.14, True]

# %%
l1.append('sparta')

# %%
l1
# Out:
# [1, 100, 2.14, True, 'sparta']

# %%
l1.append('c')

# %%
l1
# Out:
# [1, 100, 2.14, True, 'sparta', 'c']

# %%
l1.pop()
# Out:
# 'c'

# %%
l1
# Out:
# [1, 100, 2.14, True, 'sparta']

# %%
l1.reverse()

# %%
l1
# Out:
# ['sparta', True, 2.14, 100, 1]

# %%
l1.insert(1,'a')

# %%
l1
# Out:
# ['sparta', 'a', True, 2.14, 100, 1]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[315], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'bool' and 'str'

# %%
l2 = [1,2,3,45,-1,0,-22]

# %%
l2.sort()
l2
# Out:
# [-22, -1, 0, 1, 2, 3, 45]

# %%
l2 = ['a','f','b','d','x']

# %%
l2.sort()

# %%
l2
# Out:
# ['a', 'b', 'd', 'f', 'x']

# %%
l1+l2
# Out:
# ['sparta', 'a', True, 2.14, 100, 1, 'a', 'b', 'd', 'f', 'x']

# %%
l2*3
# Out:
# ['a', 'b', 'd', 'f', 'x', 'a', 'b', 'd', 'f', 'x', 'a', 'b', 'd', 'f', 'x']

# %%
l2
# Out:
# ['a', 'b', 'd', 'f', 'x']

# %%
#Dictionary

# %%
fruit = {"Apple":50,'Mango':100,'Guava':40}

# %%
fruit
# Out:
# {'Apple': 50, 'Mango': 100, 'Guava': 40}

# %%
type(fruit)
# Out:
# dict

# %%
fruit.keys()
# Out:
# dict_keys(['Apple', 'Mango', 'Guava'])

# %%
fruit.values()
# Out:
# dict_values([50, 100, 40])

# %%
fruit['Orange'] = 30

# %%
fruit['Apple'] = 90

# %%
fruit
# Out:
# {'Apple': 90, 'Mango': 100, 'Guava': 40, 'Orange': 30}

# %%
fruit.pop('Orange')
# Out:
# 30

# %%
fruit
# Out:
# {'Apple': 90, 'Mango': 100, 'Guava': 40}

# %%
fruit2 = {'Papaya': 30, 'Watermelon':35}

# %%
fruit2
# Out:
# {'Papaya': 30, 'Watermelon': 35}

# %%
fruit
# Out:
# {'Apple': 90, 'Mango': 100, 'Guava': 40}

# %%
fruit.update(fruit2)

# %%
fruit
# Out:
# {'Apple': 90, 'Mango': 100, 'Guava': 40, 'Papaya': 30, 'Watermelon': 35}

# %%
fruit2
# Out:
# {'Papaya': 30, 'Watermelon': 35}

# %%
fruit.pop("Guava")
# Out:
# 40

# %%
fruit
# Out:
# {'Apple': 90, 'Mango': 100, 'Papaya': 30, 'Watermelon': 35}

# %%
#Set

# %%
s1 = {1,'a',2.14,'sparta',2.14,'sparta'}

# %%
s1
# Out:
# {1, 2.14, 'a', 'sparta'}

# %%
type(s1)
# Out:
# set

# %%
s1.add('Hello')

# %%
s1
# Out:
# {1, 2.14, 'Hello', 'a', 'sparta'}

# %%
s1.update([10,20,30])

# %%
s1
# Out:
# {1, 10, 2.14, 20, 30, 'Hello', 'a', 'sparta'}

# %%
s1.remove('a')

# %%
 s1
# Out:
# {1, 10, 2.14, 20, 30, 'Hello', 'sparta'}

# %%
s1 = {1,2,3}
s2 = {'a','b','c'}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s2
# Out:
# {'a', 'b', 'c'}

# %%
s3 = {3,4,5}

# %%
s1.intersection(s3)
# Out:
# {3}

# %%
#If else

# %%
if(len(s1)==1):
    print(len(s1))
    print("Hello")

# %%
len(s1)
# Out:
# 3

# %%
if(len(s1)==1):
    print(len(s1))
    print("Hello")
else:
    print('Good Bye!')
# Out:
# Good Bye!

# %%
# if with tuple

# %%
tup1  = ('a','b','c')

# %%
if 'z' in tup1:
    print("Value is present in tup1")
else:
    print("Value is not present in tup1")
# Out:
# Value is not present in tup1
